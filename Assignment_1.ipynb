# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
# +
# 6

# %%
* is a mathematical operatiors
'hello' is a value
-87.8 is a value
- is a mathematical operators
/ is a mathematical operatiors
+ is a mathematical operatiors
6 isa value

# %% [markdown]
# 2. What is the difference between string and variable?

# %%
string is a combination of characters 
but variable can hold value it can even be string
a=10 ( hear a is variable where we are string 10 into it )

# %% [markdown]
# 3. Describe three different data types.

# %%
int interger its whole number like 1,2,3...
str string   its a combination of characters
float floating point numbers a whole number with decimal point 1.2,55.6,....

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?

# %%
expression is made of value 

expression represent a value

# %% [markdown]
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %%
hear what ever is after "=" that is expression (it means what ever produces a value or is a value)
statement is single entire line of code which performs some sort of action

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1

# %%
23
# Out:
# 23

# %% [markdown]
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3

# %%
int & string
# Out:
# 'spamspamspam'

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?

# %%
because variable name should not start int

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %%
as mention in question it self for 
integer its int()
floating point number its float()
string its str()

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'

# %%
"'I have eaten ' + '99' + ' burritos.'"
"or" 
'I have eaten ' + str(99) + ' burritos.'
# Out:
# 'I have eaten 99 burritos.'
