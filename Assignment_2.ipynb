# %% [markdown]
# 1.What are the two values of the Boolean data type? How do you write them?

# %%
True(1) & False(0) 
it must be written with first letter as capital becasue they r case sensitive

# %% [markdown]
# 2. What are the three different types of Boolean operators?

# %%
and or not

# %% [markdown]
# 3. Make a list of each Boolean operator's truth tables
# (i.e. every possible combination of Boolean values for the operator and what it evaluate ).

# %%
print(True and True)
print(True or True)
print(True and False)
print(True or False)
print(False and True)
print(False or  True)
print(False and False)
print(False or False)
# Out:
# True
# True
# False
# True
# False
# True
# False
# False

# %% [markdown]
# 4. What are the values of the following expressions?

# %%
(5 > 4) and (3 == 5) False
not (5 > 4) False
(5 > 4) or (3 == 5) True
not ((5 > 4) or (3 == 5)) False
(True and True) and (True == False) False
(not False) or (not True) True

# %% [markdown]
# 5. What are the six comparison operators?

# %%
< - less than symbols 
<= - less than equal to symbols
> - greater than symbol
>= - greater than equal to symbols
==  - compare
!= - not equal to

# %% [markdown]
# 6. How do you tell the difference between the equal to and assignment operators?
# Describe a condition and when you would use one.

# %%
equal is == (double =)
assignment is = (single =)

when we assign a value to variable than we use = 
like a=10

but when we write a consition comparing than we use ==

a=10
if a == 10:
    print("its correct")
else:
    print("its not correct")

# %% [markdown]
# 7. Identify the three blocks in this code:
# spam = 0
# if spam == 10:
# print('eggs')
# if spam > 5:
# print('bacon')
# else:
# print('ham')
# print('spam')
# print('spam')

# %%
spam = 0
if spam == 10:
    print('eggs')
        if spam > 5:
print('bacon')
else:
print('ham')
print('spam')
print('spam')

# %% [markdown]
# 8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.

# %%
spam = int(input("pls enter some value:"))
if spam == 1:
    print("hello")
elif spam == 2:
    print("howdy")
else:
    print("Greetings!")

# %% [markdown]
# 9.If your programme is stuck in an endless loop, what keys you’ll press?

# %%
in jupyter notebook : interpt the kernal

# %% [markdown]
# 10. How can you tell the difference between break and continue?

# %%
break is a statement where it breaks the entire loop and executes the next statement
continue is a statement where it continues the entire loop again 
(it just throws back to the loop repeating it again & again)

# %% [markdown]
# 11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?

# %%
for a in range(10), range(0, 10), and range(0, 10, 1) is same output thers is no difference

# %% [markdown]
# 12. Write a short program that prints the numbers 1 to 10 using a for loop.
# Then write an equivalent program that prints the numbers 1 to 10 using a while loop.

# %%
for loop 
for i in range(1,10):
    print(i)


while loop
a=1
while (a<=10):
    print(a)
    a=a+1

# %% [markdown]
# 13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?

# %%
spam.bocon()
